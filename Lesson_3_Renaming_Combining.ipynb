# %%
import pandas as pd

# %%
reviews = pd.read_csv("/content/winemag-data-130k-v2.csv", index_col=0)

# %%
pd.set_option('display.max_rows', 5)

# %% [markdown]
# ## Renaming in Pandas

# %%
# Change column's name
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
# Changing the index of 0
reviews.rename({0: 'firstEntry', 1: 'secondEntry', reviews.shape[0]-2: 'beforeLastEntry', reviews.shape[0]-1:'lastEntry'})
# Out:
#                   country                                        description  \
# firstEntry          Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry      Portugal  This is ripe and fruity, a wine that is smooth...
# ...                   ...                                                ...
# beforeLastEntry    France  A dry style of Pinot Gris, this is crisp with ...
# lastEntry          France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# firstEntry                        Vulkà Bianco      87    NaN
# secondEntry                           Avidagos      87   15.0
# ...                                        ...     ...    ...
# beforeLastEntry                            NaN      90   32.0
# lastEntry        Lieu-dit Harth Cuvée Caroline      90   21.0
#
#                           province region_1 region_2    taster_name  \
# ...

# %%
# Both the row index and column index can have their own name attribute.
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                    designation  points  price           province  \
# wines
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# fields region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %% [markdown]
# ## Combining in Pandas

# %%
# concat()
canadian_youtube = pd.read_csv("/content/CAvideos.csv")

# %%
british_youtube = pd.read_csv("/content/GBvideos.csv")

# %%
canadian_youtube
# Out:
#           video_id trending_date                                       title  \
# 0      n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1      0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
# ...            ...           ...                                         ...
# 40879  lbMKLzQ4cNQ      18.14.06            Trump Advisor Grovels To Trudeau
# 40880  POTgw38-m58      18.14.06            【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班
#
#          channel_title  category_id              publish_time  \
# 0           EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1            iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                ...          ...                       ...
# 40879  The Young Turks           25  2018-06-13T04:00:05.000Z
# 40880         我愛小明星大跟班           24  2018-06-13T16:00:03.000Z
#
#                                                     tags     views   likes  \
# ...

# %%
british_youtube
# Out:
#           video_id trending_date  \
# 0      Jw1Y-zhQURU      17.14.11
# 1      3s1rvMFUweQ      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0          John Lewis Christmas Ad 2017 - #MozTheMonster
# 1              Taylor Swift: …Ready for It? (Live) - SNL
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   John Lewis           26  2017-11-10T07:38:29.000Z
# 1          Saturday Night Live           24  2017-11-12T06:24:44.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %%
pd.concat([canadian_youtube, british_youtube])
# Out:
#           video_id trending_date  \
# 0      n1WpP7iowLc      17.14.11
# 1      0dBIkQ4Mz1M      17.14.11
# ...            ...           ...
# 38914  -DRsfNObKIQ      18.14.06
# 38915  4YFo4bdMO8Q      18.14.06
#
#                                                    title  \
# 0             Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                          PLUSH - Bad Unboxing Fan Mail
# ...                                                  ...
# 38914  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 38915  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                  channel_title  category_id              publish_time  \
# 0                   EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1                    iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                        ...          ...                       ...
# 38914  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# ...

# %%
# join()
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])
left = canadian_youtube.set_index(['title'])
right = british_youtube.set_index(['title'])

# %%
left
# Out:
#                                                video_id trending_date  \
# title
# Eminem - Walk On Water (Audio) ft. Beyoncé  n1WpP7iowLc      17.14.11
# PLUSH - Bad Unboxing Fan Mail               0dBIkQ4Mz1M      17.14.11
# ...                                                 ...           ...
# Trump Advisor Grovels To Trudeau            lbMKLzQ4cNQ      18.14.06
# 【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班            POTgw38-m58      18.14.06
#
#                                               channel_title  category_id  \
# title
# Eminem - Walk On Water (Audio) ft. Beyoncé       EminemVEVO           10
# PLUSH - Bad Unboxing Fan Mail                     iDubbbzTV           23
# ...                                                     ...          ...
# Trump Advisor Grovels To Trudeau            The Young Turks           25
# 【完整版】遇到恐怖情人該怎麼辦？2018.06.13小明星大跟班                   我愛小明星大跟班           24
#
#                                                         publish_time  \
# title
# ...

# %%
right
# Out:
#                                                        video_id trending_date  \
# title
# John Lewis Christmas Ad 2017 - #MozTheMonster       Jw1Y-zhQURU      17.14.11
# Taylor Swift: …Ready for It? (Live) - SNL           3s1rvMFUweQ      17.14.11
# ...                                                         ...           ...
# Eleni Foureira - Fuego - Cyprus - LIVE - First ...  -DRsfNObKIQ      18.14.06
# KYLE - Ikuyo feat.  2 Chainz & Sophia Black [Au...  4YFo4bdMO8Q      18.14.06
#
#                                                               channel_title  \
# title
# John Lewis Christmas Ad 2017 - #MozTheMonster                    John Lewis
# Taylor Swift: …Ready for It? (Live) - SNL               Saturday Night Live
# ...                                                                     ...
# Eleni Foureira - Fuego - Cyprus - LIVE - First ...  Eurovision Song Contest
# KYLE - Ikuyo feat.  2 Chainz & Sophia Black [Au...           SuperDuperKyle
#
# ...

# %%
left.join(right, lsuffix='_CAN', rsuffix='_UK')
# Out:
#                                                    video_id_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...  PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!           DvPW66IFhMI
# ...                                                         ...
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W...  Wt9Gkpmbt44
# 🚨Active Shooter at YouTube Headquarters - LIVE ...  Az72jrKbANA
#
#                                                    trending_date_CAN  \
# title
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ...          18.04.01
# #1 Fortnite World Rank - 2,323 Solo Wins!                   18.09.03
# ...                                                              ...
# 🚨 BREAKING NEWS 🔴 Raja Live all Slot Channels W...          18.07.05
# 🚨Active Shooter at YouTube Headquarters - LIVE ...          18.04.04
#
#                                                                   channel_title_CAN  \
# title
# ...
